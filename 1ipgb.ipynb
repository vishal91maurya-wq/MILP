# %% [markdown]
# # Problem

# %% [raw]
# Book: Integer and combinatorial optimization, by George L. Nemhauser and Laurence A. Wolsey
# EXERCISES Page-193
# Exercise 4.30.
# Consider the integer program
# min       √2x1 − x2:
# subject to
#           1 ≤ x2 ≤ √2x1
#           x1, x2 integer

# %% [markdown]
# Importing packages

# %%
import gurobipy as gp
from gurobipy import GRB
from math import sqrt

# %% [markdown]
# Store √2 in a var

# %%
s2 = sqrt(2)

# %% [markdown]
# Make a model named IP

# %%
m = gp.Model("IP")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2750346
# Academic license - for non-commercial use only - expires 2026-12-05

# %% [markdown]
# Make integer variables x1 and x2

# %%
x1 = m.addVar(vtype=GRB.INTEGER, name="x1")
x2 = m.addVar(vtype=GRB.INTEGER, name="x2")

# %% [markdown]
# Add constraint 1 ≤ x2 ≤ √2x1
# such constraint can't be expressed in one in python so break it in two constraints

# %%
m.addConstr(1<=x2, "c0")
m.addConstr(x2<=s2*x1, "c1")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# Add Objective min √2x1 − x2

# %%
m.setObjective(s2*x1-x2, GRB.MINIMIZE)

# %% [markdown]
# Set timelimit

# %%
m.Params.TimeLimit = 50
# Out:
# Set parameter TimeLimit to value 50

# %% [markdown]
# Solve the model

# %%
m.optimize()
# 2. Generate the presolved model
# Note: You must call update() or have some constraints for this to work
presolved_model = m.presolve()

# 3. Save the presolved model to a file to inspect it
presolved_model.write("presolved_output.lp")

# 4. Alternatively, print variables/constraints directly
print(f"Original model has {m.NumConstrs} constraints.")
print(f"Presolved model has {presolved_model.NumConstrs} constraints.")
# Out:
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) 5 120U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  50
#
# Optimize a model with 2 rows, 2 columns and 3 nonzeros (Min)
# Model fingerprint: 0xc26f31c3
# Model has 2 linear objective coefficients
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolved: 1 rows, 2 columns, 2 nonzeros
#
# Continuing optimization...
#
#
# Explored 161570 nodes (161570 simplex iterations) in 46.87 seconds (7.73 work units)
# Most recent optimization runtime was 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# ...

# %% [markdown]
# Results

# %%
for v in m.getVars():
    print(f'{v.Varname}: {v.X:g}')
print(f'Obj: {m.ObjVal:g}')

if m.status == GRB.OPTIMAL or m.status == GRB.TIME_LIMIT:
    print(f'Total solve time: {m.Runtime:.4f} seconds')
# Out:
# x1: 80782
# x2: 114243
# Obj: -5.00586e-09
# Total solve time: 0.0190 seconds
